# %% [markdown]
# # Panalyt Data Engineering Assignment
#
# By [Shubhanshu Gupta](https://shubhanshugupta.com/contact/)

# %%
import pandas as pd
import urllib.request
import json
import numpy as np

# %% [markdown]
# ### Reading the excel file

# %%
data = pd.ExcelFile('data_task.xlsx')

# %% [markdown]
# ### Reading the two sheets of excel file

# %%
job = pd.read_excel(data, 'job')
salary = pd.read_excel(data, 'salary')

# %%
job.head()
# Out:
#        Employee       Date Location Division     Emp ID
# 0  XXX501004YYY 2018-08-20     M-KL        M  XXX501004
# 1  XXX212468YYY 2018-08-06     I-HA        I  XXX212468
# 2  XXX212468YYY 2018-10-09      I-A        I  XXX212468
# 3  XXX212270YYY 2017-11-01     I-HA        I  XXX212270
# 4  XXX212270YYY 2018-10-09      I-A        I  XXX212270

# %%
salary.head()
# Out:
#        Employee Effective Date       Salary Paid Per Employee Number
# 0  XXX501004YYY     2018-08-20     MYR 7800    Month       XXX501004
# 1  XXX501004YYY     2019-04-01     MYR 8640    Month       XXX501004
# 2  XXX212468YYY     2018-08-06  IDR 4800000    Month       XXX212468
# 3  XXX212468YYY     2019-01-01  IDR 5400000    Month       XXX212468
# 4  XXX212270YYY     2017-11-01  IDR 4800000    Month       XXX212270

# %% [markdown]
# ### Splitting the location in Job dataframe to country and office. Subsequently, dropped the location column

# %%
job[['country','office']] = job['Location'].str.split('-',expand=True)

# %%
job.drop('Location', axis=1, inplace=True)
job.head()
# Out:
#        Employee       Date Division     Emp ID country office
# 0  XXX501004YYY 2018-08-20        M  XXX501004       M     KL
# 1  XXX212468YYY 2018-08-06        I  XXX212468       I     HA
# 2  XXX212468YYY 2018-10-09        I  XXX212468       I      A
# 3  XXX212270YYY 2017-11-01        I  XXX212270       I     HA
# 4  XXX212270YYY 2018-10-09        I  XXX212270       I      A

# %% [markdown]
# ### Splitting the Salary in salary dataframe to currency and salary. Subsequently, dropped the original Salary column

# %%
salary[['currency','salary']] = salary['Salary'].str.split(' ',expand=True)
salary.head()
# Out:
#        Employee Effective Date       Salary Paid Per Employee Number currency  \
# 0  XXX501004YYY     2018-08-20     MYR 7800    Month       XXX501004      MYR
# 1  XXX501004YYY     2019-04-01     MYR 8640    Month       XXX501004      MYR
# 2  XXX212468YYY     2018-08-06  IDR 4800000    Month       XXX212468      IDR
# 3  XXX212468YYY     2019-01-01  IDR 5400000    Month       XXX212468      IDR
# 4  XXX212270YYY     2017-11-01  IDR 4800000    Month       XXX212270      IDR
#
#     salary
# 0     7800
# 1     8640
# 2  4800000
# 3  5400000
# 4  4800000

# %%
salary.drop('Salary', axis=1, inplace=True)
salary.head()
# Out:
#        Employee Effective Date Paid Per Employee Number currency   salary
# 0  XXX501004YYY     2018-08-20    Month       XXX501004      MYR     7800
# 1  XXX501004YYY     2019-04-01    Month       XXX501004      MYR     8640
# 2  XXX212468YYY     2018-08-06    Month       XXX212468      IDR  4800000
# 3  XXX212468YYY     2019-01-01    Month       XXX212468      IDR  5400000
# 4  XXX212270YYY     2017-11-01    Month       XXX212270      IDR  4800000

# %% [markdown]
# ## Function to fetch current exchange rates
#
# I have created a dictionary here to store the exchange rate of the currency against USD. The idea is to store the exchange rates once and then use them (from dictionary) to convert the salary in local currency to USD.
# Used https://exchangeratesapi.io/ API for fetching exchange rates.

# %%
usd_exchange_rates = dict()
def get_usd_exchange_rates(base_currency):
    try:
        if base_currency not in usd_exchange_rates:
            contents = urllib.request.urlopen("https://api.exchangeratesapi.io/latest?base="+str(base_currency)+"&symbols=USD").read()
            exchange_rates = json.loads(contents.decode('UTF-8'))
            usd_exchange_rates[base_currency] = exchange_rates['rates']['USD']            
    except Exception as e:
        print("Error in fetching exchange rate. " + str(e))

# %%
salary.apply(lambda x: get_usd_exchange_rates(x['currency']), axis=1)
usd_exchange_rates
# Out:
# {'MYR': 0.2431293752,
#  'IDR': 7.12454e-05,
#  'PHP': 0.0195503744,
#  'THB': 0.0323464313,
#  'SGD': 0.735105827}

# %% [markdown]
# ## Function to convert local currency into USD

# %%
def get_salary_in_usd(currency, salary):
    return round(usd_exchange_rates[currency]*float(salary), 2)

# %%
# Example
get_salary_in_usd('MYR', '2800')
# Out:
# 680.76

# %% [markdown]
# ### Apply the method to the entire column

# %%
salary['usd_salary'] = salary.apply(lambda x: get_salary_in_usd(x['currency'] ,x['salary']), axis=1)

# %% [markdown]
# ### Filling all NAs with Month value

# %%
salary['Paid Per'].fillna('Month', inplace=True)

# %% [markdown]
# ### Converting the daily salary to monthly salary

# %%
salary.loc[salary['Paid Per']=='Day', 'usd_salary'] = salary.loc[salary['Paid Per']=='Day']['usd_salary']*22

# %%
salary.loc[salary['Paid Per']=='Day', 'Paid Per'] = 'Month'

# %%
salary.head()
# Out:
#        Employee Effective Date Paid Per Employee Number currency   salary  \
# 0  XXX501004YYY     2018-08-20    Month       XXX501004      MYR     7800
# 1  XXX501004YYY     2019-04-01    Month       XXX501004      MYR     8640
# 2  XXX212468YYY     2018-08-06    Month       XXX212468      IDR  4800000
# 3  XXX212468YYY     2019-01-01    Month       XXX212468      IDR  5400000
# 4  XXX212270YYY     2017-11-01    Month       XXX212270      IDR  4800000
#
#    usd_salary
# 0     1896.41
# 1     2100.64
# 2      341.98
# 3      384.73
# 4      341.98

# %%
job.head()
# Out:
#        Employee       Date Division     Emp ID country office
# 0  XXX501004YYY 2018-08-20        M  XXX501004       M     KL
# 1  XXX212468YYY 2018-08-06        I  XXX212468       I     HA
# 2  XXX212468YYY 2018-10-09        I  XXX212468       I      A
# 3  XXX212270YYY 2017-11-01        I  XXX212270       I     HA
# 4  XXX212270YYY 2018-10-09        I  XXX212270       I      A

# %%
job.shape
# Out:
# (3815, 6)

# %%
job.loc[job['Employee']=='XXX212468YYY']
# Out:
#        Employee       Date Division     Emp ID country office
# 1  XXX212468YYY 2018-08-06        I  XXX212468       I     HA
# 2  XXX212468YYY 2018-10-09        I  XXX212468       I      A

# %%
salary.loc[salary['Employee']=='XXX212468YYY']
# Out:
#        Employee Effective Date Paid Per Employee Number currency   salary  \
# 2  XXX212468YYY     2018-08-06    Month       XXX212468      IDR  4800000
# 3  XXX212468YYY     2019-01-01    Month       XXX212468      IDR  5400000
#
#    usd_salary
# 2      341.98
# 3      384.73

# %% [markdown]
# ### Doing an outer join on Job and Salary dataframes on Employee and Date columns. Retaining only Employee, Date and USD salary columns from Salary dataframe

# %%
merged_df = pd.merge(job, salary[['Employee','Effective Date', 'usd_salary']], how='outer', left_on=['Employee', 'Date'], right_on = ['Employee', 'Effective Date'])

# %%
merged_df.head()
# Out:
#        Employee       Date Division     Emp ID country office Effective Date  \
# 0  XXX501004YYY 2018-08-20        M  XXX501004       M     KL     2018-08-20
# 1  XXX212468YYY 2018-08-06        I  XXX212468       I     HA     2018-08-06
# 2  XXX212468YYY 2018-10-09        I  XXX212468       I      A            NaT
# 3  XXX212270YYY 2017-11-01        I  XXX212270       I     HA     2017-11-01
# 4  XXX212270YYY 2018-10-09        I  XXX212270       I      A            NaT
#
#    usd_salary
# 0     1896.41
# 1      341.98
# 2         NaN
# 3      341.98
# 4         NaN

# %% [markdown]
# ## Assumptions

# %% [markdown]
# 1. If an employee has record in Salary dataframe for an effective date and no record in Job dataframe for the same effective date, I have assumed that the employee was in the same division, country and office as in the preceeding row.
# 2. If an employee has a record in Job dataframe for an effective date and no record in Salary dataframe for the same effective date, I have assumed that the employee was on same salary as before (last drawn salary of the most recent effective date).

# %% [markdown]
# ### Sorting the merged dataframe by employee and date column. Doing this because I want to forward fill the NAs with the values in preceeding rows.

# %%
merged_df = merged_df.sort_values(['Employee', 'Date']).reset_index(drop=True)

# %%
# Example 1
merged_df.loc[merged_df['Employee']=='XXX101549YYY']
# Out:
#          Employee       Date Division     Emp ID country office  \
# 975  XXX101549YYY 2016-09-01        R  XXX101549       T     HQ
# 976  XXX101549YYY 2018-04-01        R  XXX101549       T     HQ
# 977  XXX101549YYY 2018-04-20        R  XXX101549       T     HQ
# 978  XXX101549YYY 2018-07-17        R  XXX101549       T     HQ
# 979  XXX101549YYY        NaT      NaN        NaN     NaN    NaN
# 980  XXX101549YYY        NaT      NaN        NaN     NaN    NaN
#
#     Effective Date  usd_salary
# 975     2016-09-01     1868.01
# 976     2018-04-01     2377.46
# 977            NaT         NaN
# 978            NaT         NaN
# 979     2017-04-01     1924.05
# 980     2019-04-01     2472.56

# %%
# Example 2
merged_df.loc[merged_df['Employee']=='XXX212468YYY']
# Out:
#           Employee       Date Division     Emp ID country office  \
# 3939  XXX212468YYY 2018-08-06        I  XXX212468       I     HA
# 3940  XXX212468YYY 2018-10-09        I  XXX212468       I      A
# 3941  XXX212468YYY        NaT      NaN        NaN     NaN    NaN
#
#      Effective Date  usd_salary
# 3939     2018-08-06      341.98
# 3940            NaT         NaN
# 3941     2019-01-01      384.73

# %% [markdown]
# ## Following Assumption number 1.
# If there's no value in Date field from Job dataframe (NAs as a result of join), I am filling the effective date from salary dataframe.

# %%
merged_df.loc[merged_df['Date'].isnull(),'Date'] = merged_df['Effective Date']

# %% [markdown]
# ## Following Assumption number 2.
# If there's no value in Date field from Salary dataframe (NAs as a result of join), I am filling the effective date from job dataframe.

# %%
merged_df.loc[merged_df['Effective Date'].isnull(),'Effective Date'] = merged_df['Date']

# %% [markdown]
# ## Forward filling the NAs

# %%
merged_df = merged_df.fillna(method='ffill')

# %%
merged_df
# Out:
#           Employee       Date Division     Emp ID country office  \
# 0     XXX101000YYY 2014-07-01        T  XXX101000       T     HQ
# 1     XXX101000YYY 2018-02-14        T  XXX101000       T     HQ
# 2     XXX101000YYY 2012-07-01        T  XXX101000       T     HQ
# 3     XXX101000YYY 2017-04-01        T  XXX101000       T     HQ
# 4     XXX101000YYY 2018-04-01        T  XXX101000       T     HQ
# 5     XXX101000YYY 2019-04-01        T  XXX101000       T     HQ
# 6     XXX101001YYY 2012-11-01        T  XXX101001       T     HQ
# 7     XXX101001YYY 2017-04-01        T  XXX101001       T     HQ
# 8     XXX101001YYY 2017-07-01        T  XXX101001       T     HQ
# 9     XXX101001YYY 2018-06-01        T  XXX101001       T     HQ
# 10    XXX101001YYY 2019-02-04        T  XXX101001       T     HQ
# 11    XXX101001YYY 2019-03-01        T  XXX101001       T     HQ
# 12    XXX101001YYY 2018-04-01        T  XXX101001       T     HQ
# 13    XXX101001YYY 2019-04-01        T  XXX101001       T     HQ
# 14    XXX101002YYY 2013-02-07        T  XXX101002       T     HQ
# 15    XXX101002YYY 2017-07-17        T  XXX101002       T     HQ
# 16    XXX101002YYY 2017-09-13        T  XXX101002       T     HQ
# 17    XXX101002YYY 2017-09-22        T  XXX101002       T     HQ
# 18    XXX101002YYY 2018-04-19        T  XXX101002       T     HQ
# 19    XXX101002YYY 2017-04-01        T  XXX101002       T     HQ
# 20    XXX101002YYY 2017-09-01        T  XXX101002       T     HQ
# 21    XXX101003YYY 2013-04-01        R  XXX101003       T     HQ
# 22    XXX101003YYY 2018-03-14        R  XXX101003       T     HQ
# 23    XXX101003YYY 2018-04-01        R  XXX101003       T     HQ
# 24    XXX101004YYY 2013-04-17        T  XXX101004       T      R
# 25    XXX101004YYY 2016-04-01        T  XXX101004       T      R
# 26    XXX101004YYY 2016-09-08        T  XXX101004       T      R
# 27    XXX101004YYY 2017-04-01        T  XXX101004       T      R
# 28    XXX101004YYY 2017-07-17        T  XXX101004       T      R
# 29    XXX101004YYY 2017-09-27        T  XXX101004       T      L
# ...            ...        ...      ...        ...     ...    ...
# 5739  XXXS00009YYY 2018-12-17        T  XXXS00009       T      L
# 5740  XXXS00009YYY 2019-03-01        T  XXXS00009       T      L
# 5741  XXXS00010YYY 2018-12-17        T  XXXS00010       T      L
# 5742  XXXS00010YYY 2019-03-01        T  XXXS00010       T      L
# 5743  XXXS00011YYY 2018-12-17        T  XXXS00011       T      L
# 5744  XXXS00011YYY 2019-03-01        T  XXXS00011       T      L
# 5745  XXXS00012YYY 2018-12-17        T  XXXS00012       T      L
# 5746  XXXS00012YYY 2019-03-01        T  XXXS00012       T      L
# 5747  XXXS00013YYY 2018-12-17        T  XXXS00013       T      L
# 5748  XXXS00013YYY 2019-03-01        T  XXXS00013       T      L
# 5749  XXXS00014YYY 2018-12-17        T  XXXS00014       T      L
# 5750  XXXS00014YYY 2019-03-01        T  XXXS00014       T      L
# 5751  XXXS00015YYY 2018-12-17        T  XXXS00015       T      L
# 5752  XXXS00015YYY 2019-03-01        T  XXXS00015       T      L
# 5753  XXXS00016YYY 2018-12-17        T  XXXS00016       T      L
# 5754  XXXS00016YYY 2019-03-01        T  XXXS00016       T      L
# 5755  XXXS00017YYY 2018-12-17        T  XXXS00017       T      L
# 5756  XXXS00017YYY 2019-03-01        T  XXXS00017       T      L
# 5757  XXXS00018YYY 2018-12-17        T  XXXS00018       T      L
# 5758  XXXS00018YYY 2019-03-01        T  XXXS00018       T      L
# 5759  XXXS00019YYY 2018-11-01        T  XXXS00019       T      L
# 5760  XXXS00019YYY 2019-01-01        T  XXXS00019       T      L
# 5761  XXXS00019YYY 2019-03-01        T  XXXS00019       T      L
# 5762  XXXS00019YYY 2018-12-01        T  XXXS00019       T      L
# 5763  XXXS00020YYY 2018-11-07        T  XXXS00020       T      L
# 5764  XXXS00020YYY 2019-01-01        T  XXXS00020       T      L
# 5765  XXXS00020YYY 2019-03-01        T  XXXS00020       T      L
# 5766  XXXS00020YYY 2018-12-01        T  XXXS00020       T      L
# 5767  XXXS00023YYY 2018-12-01        T  XXXS00023       T      L
# 5768  XXXS00023YYY 2019-03-01        T  XXXS00023       T      L
#
#      Effective Date  usd_salary
# 0        2014-07-01         NaN
# 1        2018-02-14         NaN
# 2        2012-07-01     2109.25
# 3        2017-04-01     2172.55
# 4        2018-04-01     2227.86
# 5        2019-04-01     2258.59
# 6        2012-11-01     1428.90
# 7        2017-04-01     1470.39
# 8        2017-07-01     1597.91
# 9        2018-06-01     1597.91
# 10       2019-02-04     1597.91
# 11       2019-03-01     1597.91
# 12       2018-04-01     1674.74
# 13       2019-04-01     1720.83
# 14       2013-02-07     8714.78
# 15       2017-07-17     8714.78
# 16       2017-09-13     8714.78
# 17       2017-09-22     8714.78
# 18       2018-04-19     8714.78
# 19       2017-04-01     9365.62
# 20       2017-09-01     9737.59
# 21       2013-04-01     9218.73
# 22       2018-03-14     9218.73
# 23       2018-04-01    10819.72
# 24       2013-04-17      990.38
# 25       2016-04-01      990.38
# 26       2016-09-08      990.38
# 27       2017-04-01     1086.84
# 28       2017-07-17     1086.84
# 29       2017-09-27     1086.84
# ...             ...         ...
# 5739     2018-12-17      304.26
# 5740     2019-03-01      304.26
# 5741     2018-12-17      304.26
# 5742     2019-03-01      304.26
# 5743     2018-12-17      288.20
# 5744     2019-03-01      288.20
# 5745     2018-12-17      384.34
# 5746     2019-03-01      384.34
# 5747     2018-12-17      288.20
# 5748     2019-03-01      288.20
# 5749     2018-12-17      288.20
# 5750     2019-03-01      288.20
# 5751     2018-12-17      304.26
# 5752     2019-03-01      304.26
# 5753     2018-12-17      304.26
# 5754     2019-03-01      304.26
# 5755     2018-12-17      384.34
# 5756     2019-03-01      384.34
# 5757     2018-12-17      304.26
# 5758     2019-03-01      304.26
# 5759     2018-11-01      439.34
# 5760     2019-01-01      439.34
# 5761     2019-03-01      439.34
# 5762     2018-12-01      405.68
# 5763     2018-11-07      439.34
# 5764     2019-01-01      439.34
# 5765     2019-03-01      439.34
# 5766     2018-12-01      405.68
# 5767     2018-12-01      427.02
# 5768     2019-03-01      427.02
#
# [5769 rows x 8 columns]
